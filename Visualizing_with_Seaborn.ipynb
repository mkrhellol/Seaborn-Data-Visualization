# %% [markdown]
# # **Seaborn: Statistical Data Visualization**
# by Mrinal Kanti Roy (Hellol)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# **Loading the datasets**

# %%
tips = sns.load_dataset("tips")
iris = sns.load_dataset("iris")
titanic = sns.load_dataset("titanic")
planet = sns.load_dataset("planets")

# %% [markdown]
# **Checking the Tips dataset**

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# **Scatter Plot**

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips, hue="day", size="size")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# **Histograms & Distribution Plot**

# %%
sns.histplot(tips['tip'], kde=True, bins = 20)
plt.xlabel("Tip in $")
# Out:
# Text(0.5, 0, 'Tip in $')

# %% [markdown]
# **Playing with bins size**

# %%
sns.histplot(tips['tip'], kde=True, bins = 10)
plt.xlabel("Tip in $")
# Out:
# Text(0.5, 0, 'Tip in $')

# %%
sns.histplot(tips['tip'], bins = 20)
plt.xlabel("Tip in $")
# Out:
# Text(0.5, 0, 'Tip in $')

# %%
sns.distplot(tips['tip'], kde=True, bins = 20)
plt.xlabel("Tip in $")
# Out:
# <ipython-input-140-c4b08133469e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['tip'], kde=True, bins = 20)
# Text(0.5, 0, 'Tip in $')

# %% [markdown]
# **Bar Plot**

# %%
sns.barplot(x="sex", y= "tip", data = tips, palette ="YlGnBu")
# Out:
# <ipython-input-141-7fc6d016a85f>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="sex", y= "tip", data = tips, palette ="YlGnBu")
# <Axes: xlabel='sex', ylabel='tip'>

# %% [markdown]
# **Box Plot**

# %%
sns.boxplot(x="day", y="tip", data=tips, hue = "sex", palette = "YlGnBu")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x="day", y="total_bill", data=tips,hue = "sex", palette = "YlGnBu")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# **Strip Plot**

# %%
sns.stripplot(x="day", y="tip", data=tips, palette = "YlGnBu", hue="sex", dodge = True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# **Joint Plot**

# %%
sns.jointplot(x="tip", y="total_bill", data=tips, kind="scatter", color = "r")

# %% [markdown]
# **Joint Plot with Regression**

# %%
sns.jointplot(x="tip", y="total_bill", data=tips, kind="reg", color = "g")

# %% [markdown]
# **Joint Plot with kde without and with shading**

# %%
sns.jointplot(x="tip", y="total_bill", data=tips, kind="kde", color = "b")

# %%
sns.jointplot(x="tip", y="total_bill", data=tips, kind="kde", shade = "True", cmap = "hls")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1832: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %% [markdown]
# **Hex type joint plot**

# %%
sns.jointplot(x="tip", y="total_bill", data=tips, kind="hex", cmap="YlGnBu")

# %% [markdown]
# **Checking the titanic dataset**

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# **Pair plot on titanic dataset**

# %%
sns.pairplot(titanic.select_dtypes(["number"]), hue ="pclass")

# %% [markdown]
# **Preprocessing with label encoder**

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
columns = ["adult_male", "sex","alone"]
for col in columns:
    titanic[col] = le.fit_transform(titanic[col])
titanic.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3    1  22.0      1      0   7.2500        S  Third    man
# 1         1       1    0  38.0      1      0  71.2833        C  First  woman
# 2         1       3    0  26.0      0      0   7.9250        S  Third  woman
# 3         1       1    0  35.0      1      0  53.1000        S  First  woman
# 4         0       3    1  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0           1  NaN  Southampton    no      0
# 1           0    C    Cherbourg   yes      0
# 2           0  NaN  Southampton   yes      1
# 3           0    C  Southampton   yes      0
# 4           1  NaN  Southampton    no      1

# %% [markdown]
# **Considering only numerical values**

# %%
titanicnum = titanic.select_dtypes(["number"])
titanicnum.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  adult_male  alone
# 0         0       3    1  22.0      1      0   7.2500           1      0
# 1         1       1    0  38.0      1      0  71.2833           0      0
# 2         1       3    0  26.0      0      0   7.9250           0      1
# 3         1       1    0  35.0      1      0  53.1000           0      0
# 4         0       3    1  35.0      0      0   8.0500           1      1

# %% [markdown]
# **Correlation of different factors**

# %%
titanicnum.corr()
# Out:
#             survived    pclass       sex       age     sibsp     parch  \
# survived    1.000000 -0.338481 -0.543351 -0.077221 -0.035322  0.081629
# pclass     -0.338481  1.000000  0.131900 -0.369226  0.083081  0.018443
# sex        -0.543351  0.131900  1.000000  0.093254 -0.114631 -0.245489
# age        -0.077221 -0.369226  0.093254  1.000000 -0.308247 -0.189119
# sibsp      -0.035322  0.083081 -0.114631 -0.308247  1.000000  0.414838
# parch       0.081629  0.018443 -0.245489 -0.189119  0.414838  1.000000
# fare        0.257307 -0.549500 -0.182333  0.096067  0.159651  0.216225
# adult_male -0.557080  0.094035  0.908578  0.280328 -0.253586 -0.349943
# alone      -0.203367  0.135207  0.303646  0.198270 -0.584471 -0.583398
#
#                 fare  adult_male     alone
# survived    0.257307   -0.557080 -0.203367
# pclass     -0.549500    0.094035  0.135207
# sex        -0.182333    0.908578  0.303646
# age         0.096067    0.280328  0.198270
# ...

# %% [markdown]
# **Heatmap on titanic dataset**

# %%
sns.heatmap(titanicnum.corr(), annot = True, cmap = "coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# **Iris dataset & clustermap **

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.clustermap(iris.drop("species", axis = 1))
